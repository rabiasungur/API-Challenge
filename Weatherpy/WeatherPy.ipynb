# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 580

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
query_url = url + "appid=" + weather_api_key + "&q="

# %%
# Count every 50 city as 1 set 

# record_num = 0
# set_num = 1

# for city in cities:
#     if record_num<50:
#             record_num = record_num+1
#             print(f'Processing Record {record_num} of Set {set_num} | {city}')
#         else:
#             set_num = set_num+1
#             record_num = 0

# %%
#Request max temp, humdity, windspeed etc. values of all cities from url and store them in a list to turn into dataframe later

# temp_list = []
# cloudiness_list = []
# windspeed_list = []
# humidity_list = []
# country_list = []
# dates_list = []
# lat_list = []
# lng_list = []
# maxtemp_list = []
# cities_list = []

# for city in cities[:5]:
#     response = requests.get(query_url + city).json()
# #     pprint(response)
#     try:
#         temp_list.append(response["main"]["temp"])
#         cloudiness_list.append(response["clouds"]["all"])
#         windspeed_list.append(response["wind"]["speed"])
#         humidity_list.append(response["main"]["humidity"])
#         country_list.append(response["sys"]["country"])
#         dates_list.append(response["dt"])
#         lat_list.append( response["coord"]["lat"])
#         lng_list.append(response["coord"]["lon"])
#         maxtemp_list.append(response["main"]["temp_max"])
#         cities_list.append(response["name"])
#     except:
#         print("error")

# %%
# Combine counting every set of 50 cities & taking values from response: 
# It will count and print every city when counts&print all errors when trying to take and store values
# Both actions are taken in same for loop and prints huge amount of output of every city.

# %%
print("Beginning Data Retrieval")
print("-----------------------------")
temp_list = []
cloudiness_list = []
windspeed_list = []
humidity_list = []
country_list = []
dates_list = []
lat_list = []
lng_list = []
maxtemp_list = []
cities_list = []
record_num = 0
set_num = 1

for city in cities:
    response = requests.get(query_url + city).json()
    try:
        cloudiness_list.append(response["clouds"]["all"])
        windspeed_list.append(response["wind"]["speed"])
        humidity_list.append(response["main"]["humidity"])
        country_list.append(response["sys"]["country"])
        dates_list.append(response["dt"])
        lat_list.append( response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        maxtemp_list.append(response["main"]["temp_max"])
        cities_list.append(response["name"])
        if record_num<50:
            record_num = record_num+1
            print(f'Processing Record {record_num} of Set {set_num} | {city}')
        else:
            set_num = set_num+1
            record_num = 0
    except:
        print("City not found. Skipping...")
        
print("-----------------------------")
print("Data Retrieval Complete")     
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | saint-maximin-la-sainte-baume
# Processing Record 5 of Set 1 | aketi
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | vermilion
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | husavik
# City not found. Skipping...
# Processing Record 10 of Set 1 | faanui
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | chabahar
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | nizwa
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | ayolas
# Processing Record 21 of Set 1 | caravelas
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | te anau
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | maniitsoq
# Processing Record 26 of Set 1 | fairbanks
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | rundu
# Processing Record 29 of Set 1 | geraldton
# Processing Record 30 of Set 1 | lazaro cardenas
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | mutare
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | fujishiro
# City not found. Skipping...
# Processing Record 35 of Set 1 | jurm
# Processing Record 36 of Set 1 | sao domingos do maranhao
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | baltiysk
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | ahuimanu
# Processing Record 42 of Set 1 | lata
# City not found. Skipping...
# Processing Record 43 of Set 1 | asau
# Processing Record 44 of Set 1 | altay
# Processing Record 45 of Set 1 | the valley
# Processing Record 46 of Set 1 | wajima
# Processing Record 47 of Set 1 | yuanping
# Processing Record 48 of Set 1 | atar
# Processing Record 49 of Set 1 | santa fe do sul
# Processing Record 50 of Set 1 | constitucion
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | barinas
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | babayurt
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | tautira
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | cabo san lucas
# Processing Record 11 of Set 2 | bilibino
# Processing Record 12 of Set 2 | half moon bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 2 | minturno
# Processing Record 14 of Set 2 | atambua
# Processing Record 15 of Set 2 | leh
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | miandrivazo
# Processing Record 18 of Set 2 | moose factory
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 2 | ancud
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | cidreira
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | sinfra
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | ambilobe
# Processing Record 29 of Set 2 | margate
# Processing Record 30 of Set 2 | tongliao
# Processing Record 31 of Set 2 | vila velha
# Processing Record 32 of Set 2 | mayo
# Processing Record 33 of Set 2 | mnogovershinnyy
# Processing Record 34 of Set 2 | cochrane
# Processing Record 35 of Set 2 | talnakh
# Processing Record 36 of Set 2 | khatanga
# City not found. Skipping...
# Processing Record 37 of Set 2 | deputatskiy
# Processing Record 38 of Set 2 | ust-ilimsk
# Processing Record 39 of Set 2 | stornoway
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | lagoa
# Processing Record 42 of Set 2 | saint anthony
# Processing Record 43 of Set 2 | punta de bombon
# Processing Record 44 of Set 2 | kaeo
# Processing Record 45 of Set 2 | codrington
# City not found. Skipping...
# Processing Record 46 of Set 2 | bystryy istok
# Processing Record 47 of Set 2 | viseu
# Processing Record 48 of Set 2 | dong hoi
# Processing Record 49 of Set 2 | manzanillo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 2 | avarua
# Processing Record 1 of Set 3 | chapais
# Processing Record 2 of Set 3 | kodiak
# Processing Record 3 of Set 3 | ruston
# Processing Record 4 of Set 3 | quatre cocos
# Processing Record 5 of Set 3 | guerrero negro
# Processing Record 6 of Set 3 | tiksi
# Processing Record 7 of Set 3 | kruisfontein
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | bambous virieux
# Processing Record 10 of Set 3 | ulaanbaatar
# Processing Record 11 of Set 3 | bobo dioulasso
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | nanortalik
# Processing Record 14 of Set 3 | adre
# Processing Record 15 of Set 3 | bengkulu
# Processing Record 16 of Set 3 | ajdabiya
# Processing Record 17 of Set 3 | hongjiang
# Processing Record 18 of Set 3 | mandiana
# Processing Record 19 of Set 3 | yatou
# Processing Record 20 of Set 3 | cherskiy
# Processing Record 21 of Set 3 | severo-kurilsk
# Processing Record 22 of Set 3 | chokurdakh
# Processing Record 23 of Set 3 | sabha
# City not found. Skipping...
# Processing Record 24 of Set 3 | hualmay
# Processing Record 25 of Set 3 | port lincoln
# Processing Record 26 of Set 3 | haines junction
# Processing Record 27 of Set 3 | lasa
# Processing Record 28 of Set 3 | mwinilunga
# Processing Record 29 of Set 3 | bud
# Processing Record 30 of Set 3 | plouzane
# Processing Record 31 of Set 3 | sao filipe
# Processing Record 32 of Set 3 | saint-augustin
# Processing Record 33 of Set 3 | tezu
# Processing Record 34 of Set 3 | orzhytsya
# Processing Record 35 of Set 3 | bitkine
# Processing Record 36 of Set 3 | aklavik
# Processing Record 37 of Set 3 | malakal
# Processing Record 38 of Set 3 | port hardy
# Processing Record 39 of Set 3 | ilulissat
# Processing Record 40 of Set 3 | rochefort
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | casian
# Processing Record 43 of Set 3 | oktyabrskoye
# Processing Record 44 of Set 3 | senno
# City not found. Skipping...
# Processing Record 45 of Set 3 | saint-philippe
# Processing Record 46 of Set 3 | russell
# City not found. Skipping...
# Processing Record 47 of Set 3 | nouadhibou
# Processing Record 48 of Set 3 | norman wells
# Processing Record 49 of Set 3 | mahebourg
# Processing Record 50 of Set 3 | new norfolk
# Processing Record 1 of Set 4 | broken hill
# Processing Record 2 of Set 4 | tura
# Processing Record 3 of Set 4 | aanekoski
# Processing Record 4 of Set 4 | benguela
# Processing Record 5 of Set 4 | kamaishi
# Processing Record 6 of Set 4 | chuy
# Processing Record 7 of Set 4 | souillac
# Processing Record 8 of Set 4 | vardo
# Processing Record 9 of Set 4 | parys
# Processing Record 10 of Set 4 | mae hong son
# Processing Record 11 of Set 4 | bathsheba
# Processing Record 12 of Set 4 | san vicente de canete
# Processing Record 13 of Set 4 | roma
# City not found. Skipping...
# Processing Record 14 of Set 4 | matay
# Processing Record 15 of Set 4 | itarema
# Processing Record 16 of Set 4 | tuatapere
# Processing Record 17 of Set 4 | coquimbo
# Processing Record 18 of Set 4 | rostovka
# Processing Record 19 of Set 4 | champerico
# Processing Record 20 of Set 4 | lavrentiya
# Processing Record 21 of Set 4 | kipushi
# Processing Record 22 of Set 4 | iqaluit
# Processing Record 23 of Set 4 | saldanha
# Processing Record 24 of Set 4 | anadyr
# Processing Record 25 of Set 4 | hasaki
# Processing Record 26 of Set 4 | ribeira grande
# Processing Record 27 of Set 4 | port blair
# Processing Record 28 of Set 4 | danville
# Processing Record 29 of Set 4 | hami
# City not found. Skipping...
# Processing Record 30 of Set 4 | ishinomaki
# Processing Record 31 of Set 4 | sorland
# Processing Record 32 of Set 4 | korla
# Processing Record 33 of Set 4 | santiago
# Processing Record 34 of Set 4 | sao jose da coroa grande
# Processing Record 35 of Set 4 | isangel
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | thompson
# Processing Record 38 of Set 4 | kirakira
# Processing Record 39 of Set 4 | yulara
# Processing Record 40 of Set 4 | berdigestyakh
# Processing Record 41 of Set 4 | mount gambier
# Processing Record 42 of Set 4 | boralday
# Processing Record 43 of Set 4 | luba
# Processing Record 44 of Set 4 | san andres
# Processing Record 45 of Set 4 | luderitz
# Processing Record 46 of Set 4 | werda
# Processing Record 47 of Set 4 | yabrud
# Processing Record 48 of Set 4 | torbay
# Processing Record 49 of Set 4 | le port
# Processing Record 50 of Set 4 | portland
# Processing Record 1 of Set 5 | dingle
# Processing Record 2 of Set 5 | touros
# Processing Record 3 of Set 5 | vallenar
# Processing Record 4 of Set 5 | biak
# Processing Record 5 of Set 5 | petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | lorengau
# Processing Record 7 of Set 5 | huatulco
# Processing Record 8 of Set 5 | san quintin
# Processing Record 9 of Set 5 | joshimath
# Processing Record 10 of Set 5 | tandlianwala
# Processing Record 11 of Set 5 | lebu
# Processing Record 12 of Set 5 | henties bay
# Processing Record 13 of Set 5 | saint-paul
# Processing Record 14 of Set 5 | peniche
# Processing Record 15 of Set 5 | talaya
# Processing Record 16 of Set 5 | dharchula
# Processing Record 17 of Set 5 | makakilo city
# Processing Record 18 of Set 5 | fakel
# Processing Record 19 of Set 5 | gornopravdinsk
# Processing Record 20 of Set 5 | sitka
# Processing Record 21 of Set 5 | la ronge
# Processing Record 22 of Set 5 | hamilton
# Processing Record 23 of Set 5 | nikolskoye
# Processing Record 24 of Set 5 | san carlos de bariloche
# Processing Record 25 of Set 5 | la garriga
# Processing Record 26 of Set 5 | todos santos
# Processing Record 27 of Set 5 | abha
# Processing Record 28 of Set 5 | chengam
# Processing Record 29 of Set 5 | carupano
# City not found. Skipping...
# Processing Record 30 of Set 5 | fukue
# Processing Record 31 of Set 5 | cabedelo
# Processing Record 32 of Set 5 | faya
# Processing Record 33 of Set 5 | victoria
# Processing Record 34 of Set 5 | ketchikan
# City not found. Skipping...
# Processing Record 35 of Set 5 | makubetsu
# Processing Record 36 of Set 5 | rovaniemi
# Processing Record 37 of Set 5 | cayenne
# Processing Record 38 of Set 5 | coahuayana
# Processing Record 39 of Set 5 | xiaoshi
# Processing Record 40 of Set 5 | kaitangata
# Processing Record 41 of Set 5 | sambava
# City not found. Skipping...
# Processing Record 42 of Set 5 | nouakchott
# Processing Record 43 of Set 5 | san patricio
# Processing Record 44 of Set 5 | cockburn town
# Processing Record 45 of Set 5 | kollam
# Processing Record 46 of Set 5 | buchanan
# Processing Record 47 of Set 5 | ust-tsilma
# Processing Record 48 of Set 5 | bisira
# Processing Record 49 of Set 5 | eyl
# Processing Record 50 of Set 5 | camacha
# Processing Record 1 of Set 6 | mana
# Processing Record 2 of Set 6 | udachnyy
# Processing Record 3 of Set 6 | louga
# Processing Record 4 of Set 6 | vredendal
# Processing Record 5 of Set 6 | kulim
# Processing Record 6 of Set 6 | alice springs
# Processing Record 7 of Set 6 | kudahuvadhoo
# Processing Record 8 of Set 6 | sioux lookout
# Processing Record 9 of Set 6 | mecca
# Processing Record 10 of Set 6 | lewistown
# City not found. Skipping...
# Processing Record 11 of Set 6 | santa rosa
# Processing Record 12 of Set 6 | menongue
# Processing Record 13 of Set 6 | san martin
# Processing Record 14 of Set 6 | palimbang
# Processing Record 15 of Set 6 | port-gentil
# Processing Record 16 of Set 6 | verkhnevilyuysk
# Processing Record 17 of Set 6 | beringovskiy
# Processing Record 18 of Set 6 | saumur
# Processing Record 19 of Set 6 | dapaong
# Processing Record 20 of Set 6 | dwarka
# City not found. Skipping...
# Processing Record 21 of Set 6 | muros
# Processing Record 22 of Set 6 | cairns
# Processing Record 23 of Set 6 | banjar
# Processing Record 24 of Set 6 | vila franca do campo
# Processing Record 25 of Set 6 | coos bay
# Processing Record 26 of Set 6 | clyde river
# Processing Record 27 of Set 6 | richards bay
# Processing Record 28 of Set 6 | gizo
# Processing Record 29 of Set 6 | avera
# Processing Record 30 of Set 6 | provideniya
# Processing Record 31 of Set 6 | yaan
# Processing Record 32 of Set 6 | erzin
# Processing Record 33 of Set 6 | pilar
# Processing Record 34 of Set 6 | sao joao da barra
# City not found. Skipping...
# Processing Record 35 of Set 6 | taoudenni
# Processing Record 36 of Set 6 | stromness
# Processing Record 37 of Set 6 | horsham
# Processing Record 38 of Set 6 | jimenez
# Processing Record 39 of Set 6 | moron
# Processing Record 40 of Set 6 | kisangani
# Processing Record 41 of Set 6 | thai nguyen
# Processing Record 42 of Set 6 | mogadishu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 6 | meulaboh
# Processing Record 44 of Set 6 | kiama
# Processing Record 45 of Set 6 | bubaque
# Processing Record 46 of Set 6 | bakaly
# Processing Record 47 of Set 6 | mehamn
# Processing Record 48 of Set 6 | reyes
# Processing Record 49 of Set 6 | tutoia
# Processing Record 50 of Set 6 | gejiu
# Processing Record 1 of Set 7 | awjilah
# Processing Record 2 of Set 7 | narsaq
# Processing Record 3 of Set 7 | garoua
# Processing Record 4 of Set 7 | bentiu
# Processing Record 5 of Set 7 | birobidzhan
# Processing Record 6 of Set 7 | miles city
# Processing Record 7 of Set 7 | shache
# Processing Record 8 of Set 7 | aberdeen
# Processing Record 9 of Set 7 | schwabach
# Processing Record 10 of Set 7 | hofn
# Processing Record 11 of Set 7 | tra vinh
# Processing Record 12 of Set 7 | kondoa
# Processing Record 13 of Set 7 | zhuhai
# City not found. Skipping...
# Processing Record 14 of Set 7 | tarabuco
# Processing Record 15 of Set 7 | comodoro rivadavia
# Processing Record 16 of Set 7 | christchurch
# Processing Record 17 of Set 7 | williston
# Processing Record 18 of Set 7 | sola
# Processing Record 19 of Set 7 | pangai
# Processing Record 20 of Set 7 | macamic
# Processing Record 21 of Set 7 | mancio lima
# Processing Record 22 of Set 7 | yenagoa
# Processing Record 23 of Set 7 | waw
# Processing Record 24 of Set 7 | airai
# Processing Record 25 of Set 7 | murdochville
# Processing Record 26 of Set 7 | olafsvik
# Processing Record 27 of Set 7 | santa maria
# Processing Record 28 of Set 7 | ramsar
# Processing Record 29 of Set 7 | along
# Processing Record 30 of Set 7 | ostrovnoy
# Processing Record 31 of Set 7 | kavieng
# Processing Record 32 of Set 7 | williams lake
# Processing Record 33 of Set 7 | rudnichnyy
# Processing Record 34 of Set 7 | mobaye
# City not found. Skipping...
# Processing Record 35 of Set 7 | laguna
# Processing Record 36 of Set 7 | kirovskiy
# Processing Record 37 of Set 7 | eucaliptus
# Processing Record 38 of Set 7 | banda aceh
# Processing Record 39 of Set 7 | lompoc
# Processing Record 40 of Set 7 | pevek
# Processing Record 41 of Set 7 | college
# Processing Record 42 of Set 7 | sibolga
# Processing Record 43 of Set 7 | waipawa
# Processing Record 44 of Set 7 | virginia beach
# Processing Record 45 of Set 7 | esperance
# City not found. Skipping...
# Processing Record 46 of Set 7 | araouane
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set 7 | champawat
# Processing Record 48 of Set 7 | bowen
# Processing Record 49 of Set 7 | almaznyy
# Processing Record 50 of Set 7 | claremore
# Processing Record 1 of Set 8 | boa vista
# Processing Record 2 of Set 8 | uporovo
# Processing Record 3 of Set 8 | birao
# City not found. Skipping...
# Processing Record 4 of Set 8 | am timan
# Processing Record 5 of Set 8 | tokonou
# Processing Record 6 of Set 8 | lushoto
# Processing Record 7 of Set 8 | santa isabel do rio negro
# Processing Record 8 of Set 8 | inuvik
# Processing Record 9 of Set 8 | orchard homes
# Processing Record 10 of Set 8 | great falls
# Processing Record 11 of Set 8 | newnan
# Processing Record 12 of Set 8 | collie
# Processing Record 13 of Set 8 | ambunti
# Processing Record 14 of Set 8 | havoysund
# Processing Record 15 of Set 8 | kajaani
# Processing Record 16 of Set 8 | vawkavysk
# Processing Record 17 of Set 8 | xining
# Processing Record 18 of Set 8 | sur
# Processing Record 19 of Set 8 | salalah
# Processing Record 20 of Set 8 | rocha
# City not found. Skipping...
# Processing Record 21 of Set 8 | mandalgovi
# Processing Record 22 of Set 8 | maarianhamina
# Processing Record 23 of Set 8 | axim
# Processing Record 24 of Set 8 | sala consilina
# Processing Record 25 of Set 8 | port macquarie
# Processing Record 26 of Set 8 | bonthe
# Processing Record 27 of Set 8 | kimbe
# City not found. Skipping...
# Processing Record 28 of Set 8 | omsukchan
# Processing Record 29 of Set 8 | hauzenberg
# Processing Record 30 of Set 8 | uberlandia
# Processing Record 31 of Set 8 | show low
# Processing Record 32 of Set 8 | cuamba
# Processing Record 33 of Set 8 | praya
# City not found. Skipping...
# Processing Record 34 of Set 8 | langsa
# Processing Record 35 of Set 8 | raahe
# Processing Record 36 of Set 8 | bereda
# Processing Record 37 of Set 8 | ushtobe
# Processing Record 38 of Set 8 | sangueya
# Processing Record 39 of Set 8 | eisenerz
# Processing Record 40 of Set 8 | sulangan
# Processing Record 41 of Set 8 | podor
# Processing Record 42 of Set 8 | panaba
# Processing Record 43 of Set 8 | leningradskiy
# Processing Record 44 of Set 8 | nemuro
# Processing Record 45 of Set 8 | naze
# City not found. Skipping...
# Processing Record 46 of Set 8 | klaksvik
# Processing Record 47 of Set 8 | qasigiannguit
# City not found. Skipping...
# Processing Record 48 of Set 8 | nagato
# City not found. Skipping...
# Processing Record 49 of Set 8 | evanston
# Processing Record 50 of Set 8 | columbus
# Processing Record 1 of Set 9 | ravar
# Processing Record 2 of Set 9 | jibuti
# Processing Record 3 of Set 9 | porbandar
# Processing Record 4 of Set 9 | grand gaube
# Processing Record 5 of Set 9 | katsuura
# Processing Record 6 of Set 9 | egvekinot
# Processing Record 7 of Set 9 | shelburne
# Processing Record 8 of Set 9 | ouesso
# Processing Record 9 of Set 9 | varhaug
# Processing Record 10 of Set 9 | shingu
# Processing Record 11 of Set 9 | ugoofaaru
# Processing Record 12 of Set 9 | vao
# Processing Record 13 of Set 9 | palembang
# Processing Record 14 of Set 9 | helong
# Processing Record 15 of Set 9 | ponta delgada
# Processing Record 16 of Set 9 | ust-nera
# Processing Record 17 of Set 9 | praia
# Processing Record 18 of Set 9 | kemijarvi
# Processing Record 19 of Set 9 | khani
# Processing Record 20 of Set 9 | pisco
# Processing Record 21 of Set 9 | pangnirtung
# City not found. Skipping...
# Processing Record 22 of Set 9 | flinders
# Processing Record 23 of Set 9 | bunbury
# Processing Record 24 of Set 9 | sumbe
# Processing Record 25 of Set 9 | ossora
# Processing Record 26 of Set 9 | kalaisan
# Processing Record 27 of Set 9 | yerbogachen
# Processing Record 28 of Set 9 | grand baie
# Processing Record 29 of Set 9 | beloha
# Processing Record 30 of Set 9 | jahazpur
# Processing Record 31 of Set 9 | huarmey
# Processing Record 32 of Set 9 | bonavista
# Processing Record 33 of Set 9 | baykit
# Processing Record 34 of Set 9 | finspang
# Processing Record 35 of Set 9 | roanoke rapids
# Processing Record 36 of Set 9 | baruun-urt
# Processing Record 37 of Set 9 | jieshi
# Processing Record 38 of Set 9 | wau
# Processing Record 39 of Set 9 | tagusao
# Processing Record 40 of Set 9 | watertown
# Processing Record 41 of Set 9 | sovetskiy
# Processing Record 42 of Set 9 | sinnamary
# City not found. Skipping...
# Processing Record 43 of Set 9 | san vicente
# Processing Record 44 of Set 9 | vila do maio
# Processing Record 45 of Set 9 | lusambo
# Processing Record 46 of Set 9 | nanga eboko
# Processing Record 47 of Set 9 | numan
# Processing Record 48 of Set 9 | acari
# Processing Record 49 of Set 9 | krasnoselkup
# Processing Record 50 of Set 9 | winslow
# Processing Record 1 of Set 10 | zabid
# Processing Record 2 of Set 10 | krasnyy chikoy
# Processing Record 3 of Set 10 | emba
# Processing Record 4 of Set 10 | khandyga
# City not found. Skipping...
# Processing Record 5 of Set 10 | praia da vitoria
# Processing Record 6 of Set 10 | coolum beach
# Processing Record 7 of Set 10 | port pirie
# Processing Record 8 of Set 10 | broome
# Processing Record 9 of Set 10 | yeppoon
# Processing Record 10 of Set 10 | bay roberts
# Processing Record 11 of Set 10 | alofi
# Processing Record 12 of Set 10 | kharabali
# Processing Record 13 of Set 10 | poum
# Processing Record 14 of Set 10 | borazjan
# Processing Record 15 of Set 10 | camabatela
# Processing Record 16 of Set 10 | general roca
# Processing Record 17 of Set 10 | liberty
# Processing Record 18 of Set 10 | kamenka
# Processing Record 19 of Set 10 | mahon
# Processing Record 20 of Set 10 | luoyang
# Processing Record 21 of Set 10 | kysyl-syr
# Processing Record 22 of Set 10 | sao desiderio
# City not found. Skipping...
# Processing Record 23 of Set 10 | quang ngai
# City not found. Skipping...
# Processing Record 24 of Set 10 | mpongwe
# Processing Record 25 of Set 10 | miri
# City not found. Skipping...
# Processing Record 26 of Set 10 | marawi
# Processing Record 27 of Set 10 | shahreza
# Processing Record 28 of Set 10 | chulman
# Processing Record 29 of Set 10 | komsomolskiy
# Processing Record 30 of Set 10 | juegang
# Processing Record 31 of Set 10 | singaraja
# Processing Record 32 of Set 10 | fort nelson
# Processing Record 33 of Set 10 | kahului
# Processing Record 34 of Set 10 | north bay
# Processing Record 35 of Set 10 | oksfjord
# City not found. Skipping...
# Processing Record 36 of Set 10 | goderich
# Processing Record 37 of Set 10 | usinsk
# Processing Record 38 of Set 10 | arinos
# Processing Record 39 of Set 10 | biloela
# Processing Record 40 of Set 10 | tevaitoa
# Processing Record 41 of Set 10 | hattiesburg
# Processing Record 42 of Set 10 | xai-xai
# Processing Record 43 of Set 10 | oranjemund
# Processing Record 44 of Set 10 | ypsonas
# Processing Record 45 of Set 10 | katsina
# Processing Record 46 of Set 10 | honiara
# Processing Record 47 of Set 10 | tateyama
# Processing Record 48 of Set 10 | caracoli
# Processing Record 49 of Set 10 | valparaiso
# Processing Record 50 of Set 10 | dali
# Processing Record 1 of Set 11 | puerto palomas
# Processing Record 2 of Set 11 | barstow
# City not found. Skipping...
# Processing Record 3 of Set 11 | kiunga
# Processing Record 4 of Set 11 | santa catarina de tepehuanes
# Processing Record 5 of Set 11 | perth
# Processing Record 6 of Set 11 | srednekolymsk
# Processing Record 7 of Set 11 | huilong
# Processing Record 8 of Set 11 | manokwari
# Processing Record 9 of Set 11 | bouca
# Processing Record 10 of Set 11 | tilichiki
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 11 | natal
# Processing Record 12 of Set 11 | le mee-sur-seine
# Processing Record 13 of Set 11 | grand haven
# Processing Record 14 of Set 11 | sakakah
# Processing Record 15 of Set 11 | cap-aux-meules
# Processing Record 16 of Set 11 | montepuez
# Processing Record 17 of Set 11 | slavsk
# Processing Record 18 of Set 11 | yzeure
# Processing Record 19 of Set 11 | ostersund
# Processing Record 20 of Set 11 | pecanha
# Processing Record 21 of Set 11 | dunedin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print(len(cloudiness_list))
print(len(windspeed_list))
print(len(humidity_list)) 
print(len(country_list)) 
print(len(dates_list)) 
print(len(lat_list)) 
print(len(lng_list)) 
print(len(maxtemp_list)) 
print(len(cities_list))
# Out:
# 531
# 531
# 531
# 531
# 531
# 531
# 531
# 531
# 531

# %%
weather_data = pd.DataFrame({"City":cities_list, "Lat":lat_list, "Lng":lng_list, "Max Temp":maxtemp_list, "Humidity":humidity_list, 
                             "Cloudiness":cloudiness_list, "Wind Speed":windspeed_list, "Country":country_list, "Date":dates_list})

# %%
weather_data.count()
# Out:
# City          531
# Lat           531
# Lng           531
# Max Temp      531
# Humidity      531
# Cloudiness    531
# Wind Speed    531
# Country       531
# Date          531
# dtype: int64

# %%
weather_data.head()
# Out:
#                             City    Lat     Lng  Max Temp  Humidity  \
# 0                    Tuktoyaktuk  69.45 -133.04    267.15        73
# 1                         Hobart -42.88  147.33    283.15        66
# 2                         Albany  42.60  -73.97    287.59        18
# 3  Saint-Maximin-la-Sainte-Baume  43.45    5.86    288.15        93
# 4                          Aketi   2.74   23.78    296.93        75
#
#    Cloudiness  Wind Speed Country        Date
# 0          75        3.60      CA  1589408723
# 1          75        6.20      AU  1589408497
# 2           1        3.58      US  1589408515
# 3          72        1.71      FR  1589408848
# 4          87        0.59      CD  1589408848

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  531.000000  531.000000  531.000000  531.000000  531.000000  531.000000
# mean    19.918870   17.191205  289.831375   69.802260   47.143126    3.487891
# std     33.398913   91.188660    9.476135   22.631929   38.093062    2.376966
# min    -54.800000 -179.170000  266.150000    3.000000    0.000000    0.350000
# 25%     -8.915000  -62.460000  283.360000   58.000000    5.000000    1.650000
# 50%     22.810000   19.930000  290.370000   76.000000   40.000000    2.720000
# 75%     47.460000   99.480000  298.160000   87.000000   84.500000    4.970000
# max     78.220000  179.320000  307.150000  100.000000  100.000000   12.300000
#
#                Date
# count  5.310000e+02
# mean   1.589409e+09
# std    1.433785e+02
# min    1.589408e+09
# 25%    1.589409e+09
# 50%    1.589409e+09
# 75%    1.589409e+09
# max    1.589409e+09

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_overhundred = weather_data.loc[weather_data['Humidity'] > 100]
humidity_overhundred.index
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
quartiles

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", edgecolors="black")
plt.title("City Latitude vs. Max Temp")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", edgecolors="black")
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", edgecolors="black")
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", edgecolors="black")
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_data=weather_data.loc[weather_data['Lat'] > 0]
southern_data=weather_data.loc[weather_data['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
n_lat = northern_data["Lat"]
n_maxtemp = northern_data["Max Temp"]

x_values = n_lat
y_values = n_maxtemp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(100,300),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

print(f"The equation of the regression line is: {line_eq}")
# Out:
# The equation of the regression line is: y = -0.45x + 306.18

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s_lat = northern_data["Lat"]
s_maxtemp = northern_data["Max Temp"]

x_values = s_lat
y_values = s_maxtemp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(100,300),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

print(f"The equation of the regression line is: {line_eq}")
# Out:
# The equation of the regression line is: y = -0.45x + 306.18

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
n_lat = northern_data["Lat"]
n_humidity = northern_data["Humidity"]

x_values = n_lat
y_values = n_humidity
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(100,70),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

print(f"The equation of the regression line is: {line_eq}")
# Out:
# The equation of the regression line is: y = 0.16x + 60.67

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s_lat = northern_data["Lat"]
s_humidity = northern_data["Humidity"]

x_values = s_lat
y_values = s_humidity
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(100,70),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

print(f"The equation of the regression line is: {line_eq}")
# Out:
# The equation of the regression line is: y = 0.16x + 60.67

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
n_lat = northern_data["Lat"]
n_cloudiness = northern_data["Cloudiness"]

x_values = n_lat
y_values = n_cloudiness
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(100,70),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

print(f"The equation of the regression line is: {line_eq}")
# Out:
# The equation of the regression line is: y = 0.17x + 42.42

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s_lat = northern_data["Lat"]
s_cloudiness = northern_data["Cloudiness"]

x_values = s_lat
y_values = s_cloudiness
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(100,70),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

print(f"The equation of the regression line is: {line_eq}")
# Out:
# The equation of the regression line is: y = 0.17x + 42.42

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
n_lat = northern_data["Lat"]
n_windspeed = northern_data["Wind Speed"]

x_values = n_lat
y_values = n_windspeed
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(100,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

print(f"The equation of the regression line is: {line_eq}")
# Out:
# The equation of the regression line is: y = 0.01x + 3.11

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s_lat = northern_data["Lat"]
s_windspeed = northern_data["Wind Speed"]

x_values = s_lat
y_values = s_windspeed
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(100,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

print(f"The equation of the regression line is: {line_eq}")
# Out:
# The equation of the regression line is: y = 0.01x + 3.11
